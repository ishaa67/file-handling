# %%
#1. Create a student record system that allows adding student data (name, roll, marks) and saving the data to a file.
file5=open("Student Record","w")
file5.write("Student Record system\nFirst Name=Isha\nLast Name =Sherkhane\nAge = 17\nLocation = Kalayan\n")
file5.close()

file5=open("Student Record","a")
file5.write("Marks=98")

file5=open("Student Record","r")
print(file5.readline())
print(file5.readline())
print(file5.readline())
print(file5.readline())
print(file5.readline())
print(file5.readline())
# Out:
# Student Record system
#
# First Name=Isha
#
# Last Name =Sherkhane
#
# Age = 17
#
# Location = Kalayan
#
# Marks=98

# %%
#2. Implement search functionality to find a student by roll number.
rollno=input("Enter Roll no of student to search:")
file=open("Search.txt","w")
file.write("101 Isha=98\n102 Sara=90\n103 Meera=86\n104 Sangita=87")
file.close()

file=open("Search.txt","r")
record=file.readlines()
#print(record)
for student in record:
    if rollno in student:
        print(student)

file.close()
# Out:
# Enter Roll no of student to search: 101
# 101 Isha=98

# %%
##3. Add functionality to update student marks.
#file6=open("update.txt","x")
#file6.close()


#write in file

file6=open("update.txt","w")
file6.write("101 Isha=98\n102 Sara=90\n103 Meera=86\n104 Sangita=87")
file6.close()
#to read file
file6=open("update.txt","r")
marks=file6.readlines()
file6.close()


#to update the file
update=marks[1]="102 sara=91\n"
file6=open("update.txt","w")
file6.writelines(marks)
file6.close()

#to read updated file
file6 = open("update.txt", "r")
print(file6.read())
file6.close()
# Out:
# <built-in method read of _io.TextIOWrapper object at 0x00000191FEA16A40>
# 101 Isha=98
# 102 sara=91
# 103 Meera=86
# 104 Sangita=87

# %%
#5. Show all student records sorted by marks
#file7=open("sorted.txt","x")
#file7.close()



file7=open("sorted.txt","w")
file7.write("104 Isha=98\n103 Sara=90\n102 Meera=86\n101 Sangita=87\n")
file7.close()


file7=open("sorted.txt","r")
lines=file7.readlines()
file7.close()

sort_lines=sorted(lines)
print(sort_lines)

file7=open("sorted.txt","w")
file7.writelines(sort_lines)
file7.close()
file7.close()

# %%
6. Display student records with marks greater than 75
#file8=open("Greater than 75.txt","x")
#file8.close()

file8=open("Greater than 75.txt","w")
file8.write("Isha = 98\nsara = 70\nrina = 75\nsameera = 90\nroka = 80")
file8.close()


file8=open("Greater than 75.txt","r")
marks=file8.readlines()
print(marks)

file8=open("Greater than 75.txt","w")

for mark in marks:
    data=mark.split()
    if int(data[2])>75:
        file8.write(mark)
file8.close()

# %%
# 10. Create a menu-driven system (Add, View, Search, Update, Delete, Exit).

while True:
    print("STUDENT RECORD MENU")
    print("1.Add Student")
    print("2.view Student")
    print("3 Search Student")
    print("4.update Student")
    print("5.Delete Student")
    print("6.Exit")
    
    choice=int(input("Enter Your choise Between1 to 6:"))
    if choice==1:
        rollno=input("Enter Roll No:")
        name=input("Enter your name:")
  
        file1=open("Studenta Record.txt","a")
        file1.write(rollno+" "+name+" \n")
        file1.close()

        print("Student add successfully")

    elif choice==2:
        file1=open("Studenta Record.txt","r")
        print(file1.read())
        file1.close()
        print("Student View successfully")

    elif choice==3:
        rollno=input("Enter roll no to search student:")
        file1=open("Studenta Record.txt","r")
        records=file1.readlines()
        print(records)
        for record in records:
            if rollno in record:
                print(record)

        file1.close()

    elif choice==4:
        update=records[1]="101 sara"
        file1=open("Studenta Record.txt","w")
        file1.writelines(update)
        file1.close()
        file1 = open("Studenta Record.txt", "r")
        print(file1.read())
        file1.close()

    elif choice ==5:
        
         rollno = input("Enter Roll No to Delete: ")

         file1 = open("Studenta.txt", "r")
         records = file1.readlines()
         file1.close()

         file1 = open("Studenta.txt", "w")

         for record in records:
             if rollno not in record:
                 file.write(record)

    file1.close()
# Out:
# STUDENT RECORD MENU
# 1.Add Student
# 2.view Student
# 3 Search Student
# 4.update Student
# 5.Delete Student
# 6.Exit
# Enter Your choise Between1 to 6: 1
# Enter Roll No: 101
# Enter your name: isha
# Student add successfully
# STUDENT RECORD MENU
# 1.Add Student
# 2.view Student
# 3 Search Student
# 4.update Student
# 5.Delete Student
# 6.Exit
# Enter Your choise Between1 to 6: 2
# 101 Isha
# 102 sara
# 103 rina
# 104 meera
# 105 vina 101 isha
# 102 mera
# 101 isha
#
# Student View successfully
# STUDENT RECORD MENU
# 1.Add Student
# 2.view Student
# 3 Search Student
# 4.update Student
# 5.Delete Student
# 6.Exit
# Enter Your choise Between1 to 6: 3
# Enter roll no to search student: 101
# ['101 Isha\n', '102 sara\n', '103 rina\n', '104 meera\n', '105 vina 101 isha \n', '102 mera \n', '101 isha \n']
# 101 Isha
#
# 105 vina 101 isha
#
# 101 isha
#
# STUDENT RECORD MENU
# 1.Add Student
# 2.view Student
# 3 Search Student
# 4.update Student
# 5.Delete Student
# 6.Exit
# ...
